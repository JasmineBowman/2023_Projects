# %%
import pandas
data_dir = 'csv_data.csv'
dt = pandas.read_csv(data_dir)

# %%
dt
# Out:
#     id             name  price  sales          brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink    NaN    NaN           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    NaN  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
dt.values
# Out:
# array([[101, 'biscuits', 5.0, 227.0, 'HomeFoods'],
#        [102, 'cookies', 7.25, 158.0, 'TBakery'],
#        [103, 'cake', 12.0, 50.0, 'TBakery'],
#        [104, 'whey_supplement', 34.9, 24.0, 'MusleUp'],
#        [105, 'soft_drink', nan, nan, 'Kola'],
#        [106, 'potato_chips', 1.75, 121.0, 'HomeFoods'],
#        [107, 'noodles', 0.99, nan, 'InstantNoodle'],
#        [108, 'protein_bars', 4.9, 85.0, 'MuscleUp']], dtype=object)

# %%
import pandas
data_dir = 'json_data.json'
dt = pandas.read_json(data_dir)

# %%
dt
# Out:
#     id             name  price  sales      brand
# 0  101         biscuits   5.00    227  HomeFoods
# 1  102          cookies   7.25    158    TBakery
# 2  103             cake  12.00     50    TBakery
# 3  104  whey_supplement  34.90     24   MuscleUp
# 4  105     protein_bars   4.90     85   MuscleUp
# 5  106     potato_chips   1.75    121  HomeFoods

# %%
import pandas
dt = pandas.read_csv('csv_data.csv')

# %%
dt
# Out:
#     id             name  price  sales          brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink    NaN    NaN           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    NaN  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
import pandas
dt = pandas.read_csv('csv_data.csv',
                    names = ['ID', 'Names', 'Price', 'Sales', 'Brand'])
dt
# Out:
#     ID            Names  Price  Sales          Brand
# 0   id             name  price  sales          brand
# 1  101         biscuits      5    227      HomeFoods
# 2  102          cookies   7.25    158        TBakery
# 3  103             cake     12     50        TBakery
# 4  104  whey_supplement   34.9     24        MusleUp
# 5  105       soft_drink    NaN    NaN           Kola
# 6  106     potato_chips   1.75    121      HomeFoods
# 7  107          noodles   0.99    NaN  InstantNoodle
# 8  108     protein_bars    4.9     85       MuscleUp

# %%
import pandas
dt = pandas.read_csv('csv_data.csv',
                    names = ['ID', 'Names', 'Price', 'Sales', 'Brand'],
                    skiprows = 1)
dt
# Out:
#     ID            Names  Price  Sales          Brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink    NaN    NaN           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    NaN  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
dt.isnull()
# Out:
#       ID  Names  Price  Sales  Brand
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 3  False  False  False  False  False
# 4  False  False   True   True  False
# 5  False  False  False  False  False
# 6  False  False  False   True  False
# 7  False  False  False  False  False

# %%
dt.fillna(0)
# Out:
#     ID            Names  Price  Sales          Brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink   0.00    0.0           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    0.0  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
dt.fillna('None')
# Out:
#     ID            Names Price  Sales          Brand
# 0  101         biscuits   5.0  227.0      HomeFoods
# 1  102          cookies  7.25  158.0        TBakery
# 2  103             cake  12.0   50.0        TBakery
# 3  104  whey_supplement  34.9   24.0        MusleUp
# 4  105       soft_drink  None   None           Kola
# 5  106     potato_chips  1.75  121.0      HomeFoods
# 6  107          noodles  0.99   None  InstantNoodle
# 7  108     protein_bars   4.9   85.0       MuscleUp

# %%
dt.pad()
# Out:
#     ID            Names  Price  Sales          Brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink  34.90   24.0           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99  121.0  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
dt.bfill()
# Out:
#     ID            Names  Price  Sales          Brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink   1.75  121.0           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99   85.0  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
import pandas
dt = pandas.read_csv('csv_data.csv',
                    names = ['ID', 'Names', 'Price', 'Sales', 'Brand'],
                    skiprows = 1)
dt
# Out:
#     ID            Names  Price  Sales          Brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink    NaN    NaN           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    NaN  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
dt.dropna()
# Out:
#     ID            Names  Price  Sales      Brand
# 0  101         biscuits   5.00  227.0  HomeFoods
# 1  102          cookies   7.25  158.0    TBakery
# 2  103             cake  12.00   50.0    TBakery
# 3  104  whey_supplement  34.90   24.0    MusleUp
# 5  106     potato_chips   1.75  121.0  HomeFoods
# 7  108     protein_bars   4.90   85.0   MuscleUp

# %%
import pandas
dt = pandas.read_csv('csv_data.csv',
                    names = ['ID', 'Names', 'Price', 'Sales', 'Brand'],
                    skiprows = 1)
dt
# Out:
#     ID            Names  Price  Sales          Brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink    NaN    NaN           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    NaN  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
dt.drop([4,6])
# Out:
#     ID            Names  Price  Sales      Brand
# 0  101         biscuits   5.00  227.0  HomeFoods
# 1  102          cookies   7.25  158.0    TBakery
# 2  103             cake  12.00   50.0    TBakery
# 3  104  whey_supplement  34.90   24.0    MusleUp
# 5  106     potato_chips   1.75  121.0  HomeFoods
# 7  108     protein_bars   4.90   85.0   MuscleUp

# %%
import pandas
dt = pandas.read_csv('csv_data.csv',
                    names = ['ID', 'Names', 'Price', 'Sales', 'Brand'],
                    skiprows = 1)
dt
# Out:
#     ID            Names  Price  Sales          Brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink    NaN    NaN           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    NaN  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
del(dt['Price'])
del(dt['Sales'])
dt
# Out:
#     ID            Names          Brand
# 0  101         biscuits      HomeFoods
# 1  102          cookies        TBakery
# 2  103             cake        TBakery
# 3  104  whey_supplement        MusleUp
# 4  105       soft_drink           Kola
# 5  106     potato_chips      HomeFoods
# 6  107          noodles  InstantNoodle
# 7  108     protein_bars       MuscleUp

# %%
import pandas
dt = pandas.read_csv('csv_data.csv',
                    names = ['ID', 'Names', 'Price', 'Sales', 'Brand'],
                    skiprows = 1)
dt
# Out:
#     ID            Names  Price  Sales          Brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink    NaN    NaN           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    NaN  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
dt.drop(columns = ['Price', 'Sales'])
# Out:
#     ID            Names          Brand
# 0  101         biscuits      HomeFoods
# 1  102          cookies        TBakery
# 2  103             cake        TBakery
# 3  104  whey_supplement        MusleUp
# 4  105       soft_drink           Kola
# 5  106     potato_chips      HomeFoods
# 6  107          noodles  InstantNoodle
# 7  108     protein_bars       MuscleUp

# %%
import pandas
dt = pandas.read_csv('csv_data.csv')
dt
# Out:
#     id             name  price  sales          brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink    NaN    NaN           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    NaN  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
import pandas
dt = pandas.read_csv('csv_data.csv', names = ['ID', 'Names', 'Price', 'Sales', 'Brand'],
                    skiprows = 1)
dt
# Out:
#     ID            Names  Price  Sales          Brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink    NaN    NaN           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    NaN  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
dt.fillna(0)
# Out:
#     ID            Names  Price  Sales          Brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink   0.00    0.0           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    0.0  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
import pandas
dt = pandas.read_csv('csv_data.csv', names = ['ID', 'Names', 'Price', 'Sales', 'Brand'],
                    skiprows = 1)
dt.fillna(0, inplace = True)
dt
# Out:
#     ID            Names  Price  Sales          Brand
# 0  101         biscuits   5.00  227.0      HomeFoods
# 1  102          cookies   7.25  158.0        TBakery
# 2  103             cake  12.00   50.0        TBakery
# 3  104  whey_supplement  34.90   24.0        MusleUp
# 4  105       soft_drink   0.00    0.0           Kola
# 5  106     potato_chips   1.75  121.0      HomeFoods
# 6  107          noodles   0.99    0.0  InstantNoodle
# 7  108     protein_bars   4.90   85.0       MuscleUp

# %%
dt['Sales']
# Out:
# 0    227.0
# 1    158.0
# 2     50.0
# 3     24.0
# 4      0.0
# 5    121.0
# 6      0.0
# 7     85.0
# Name: Sales, dtype: float64

# %%
dt['Sales'].sum()
# Out:
# 665.0

# %%
dt['Sales'].min()
# Out:
# 0.0

# %%
dt['Sales'].max()
# Out:
# 227.0

# %%
dt['Sales'].mean()
# Out:
# 83.125

# %%
round(dt['Sales'].mean())
# Out:
# 83

# %%
round(dt['Sales'].mean(), 2)
# Out:
# 83.12

# %%
dt['Sales'].median()
# Out:
# 67.5

# %%
dt['Sales'].mode()
# Out:
# 0    0.0
# Name: Sales, dtype: float64

# %%
analytics = pandas.DataFrame({'Total Sales': dt['Sales'].sum(),
                             'Average Sales':dt['Sales'].mean(),
                              'Max Sale':dt['Sales'].max()},
                            index = [1])
analytics
# Out:
#    Total Sales  Average Sales  Max Sale
# 1        665.0         83.125     227.0

# %%
dt.describe()
# Out:
#               ID     Price       Sales
# count    8.00000   8.00000    8.000000
# mean   104.50000   8.34875   83.125000
# std      2.44949  11.40183   81.202459
# min    101.00000   0.00000    0.000000
# 25%    102.75000   1.56000   18.000000
# 50%    104.50000   4.95000   67.500000
# 75%    106.25000   8.43750  130.250000
# max    108.00000  34.90000  227.000000

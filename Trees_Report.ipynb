# %%
import pandas as pan
data = pan.read_csv('trees.csv')
data
# Out:
#     Index  Girth (in)  Height (ft)  Volume(ft^3)
# 0     1.0         8.3         70.0          10.3
# 1     2.0         8.6         65.0          10.3
# 2     3.0         8.8         63.0          10.2
# 3     4.0        10.5         72.0          16.4
# 4     5.0        10.7         81.0          18.8
# 5     6.0        10.8         83.0          19.7
# 6     7.0        11.0         66.0          15.6
# 7     8.0        11.0         75.0          18.2
# 8     9.0        11.1         80.0          22.6
# 9    10.0        11.2         75.0          19.9
# 10   11.0        11.3         79.0          24.2
# 11   12.0        11.4         76.0          21.0
# 12   13.0        11.4         76.0          21.4
# 13   14.0        11.7         69.0          21.3
# 14   15.0        12.0         75.0          19.1
# 15   16.0        12.9         74.0          22.2
# 16   17.0        12.9         85.0          33.8
# 17   18.0        13.3         86.0          27.4
# 18   19.0        13.7         71.0          25.7
# 19   20.0        13.8         64.0          24.9
# 20   21.0        14.0         78.0          34.5
# 21   22.0        14.2         80.0          31.7
# 22   23.0        14.5         74.0          36.3
# 23   24.0        16.0         72.0          38.3
# 24   25.0        16.3         77.0          42.6
# 25   26.0        17.3         81.0          55.4
# 26   27.0        17.5         82.0          55.7
# 27   28.0        17.9         80.0          58.3
# 28   29.0        18.0         80.0          51.5
# 29   30.0        18.0         80.0          51.0
# 30   31.0        20.6         87.0          77.0
# 31    NaN         NaN          NaN           NaN

# %%
import pandas as pan
data = pan.read_csv('trees.csv', 
                   names = ['I', 'Girth', 'Height', 'Volume'])
del data['I']
data
# Out:
#          Girth       Height        Volume
# 0   Girth (in)  Height (ft)  Volume(ft^3)
# 1          8.3           70          10.3
# 2          8.6           65          10.3
# 3          8.8           63          10.2
# 4         10.5           72          16.4
# 5         10.7           81          18.8
# 6         10.8           83          19.7
# 7           11           66          15.6
# 8           11           75          18.2
# 9         11.1           80          22.6
# 10        11.2           75          19.9
# 11        11.3           79          24.2
# 12        11.4           76            21
# 13        11.4           76          21.4
# 14        11.7           69          21.3
# 15          12           75          19.1
# 16        12.9           74          22.2
# 17        12.9           85          33.8
# 18        13.3           86          27.4
# 19        13.7           71          25.7
# 20        13.8           64          24.9
# 21          14           78          34.5
# 22        14.2           80          31.7
# 23        14.5           74          36.3
# 24          16           72          38.3
# 25        16.3           77          42.6
# 26        17.3           81          55.4
# 27        17.5           82          55.7
# 28        17.9           80          58.3
# 29          18           80          51.5
# 30          18           80            51
# 31        20.6           87            77
# 32         NaN          NaN           NaN

# %%
import pandas as pan
data = pan.read_csv('trees.csv', 
                   names = ['I', 'Girth', 'Height', 'Volume'])
del data['I']
data.drop(0, inplace=True)
data
# Out:
#    Girth Height Volume
# 1    8.3     70   10.3
# 2    8.6     65   10.3
# 3    8.8     63   10.2
# 4   10.5     72   16.4
# 5   10.7     81   18.8
# 6   10.8     83   19.7
# 7     11     66   15.6
# 8     11     75   18.2
# 9   11.1     80   22.6
# 10  11.2     75   19.9
# 11  11.3     79   24.2
# 12  11.4     76     21
# 13  11.4     76   21.4
# 14  11.7     69   21.3
# 15    12     75   19.1
# 16  12.9     74   22.2
# 17  12.9     85   33.8
# 18  13.3     86   27.4
# 19  13.7     71   25.7
# 20  13.8     64   24.9
# 21    14     78   34.5
# 22  14.2     80   31.7
# 23  14.5     74   36.3
# 24    16     72   38.3
# 25  16.3     77   42.6
# 26  17.3     81   55.4
# 27  17.5     82   55.7
# 28  17.9     80   58.3
# 29    18     80   51.5
# 30    18     80     51
# 31  20.6     87     77
# 32   NaN    NaN    NaN

# %%
import pandas as pan
data = pan.read_csv('trees.csv', 
                   names = ['I', 'Girth', 'Height', 'Volume'])
del data['I']
data.drop(0, inplace=True)
data['Girth'] = data['Girth'].astype(float)
data['Height'] = data['Height'].astype(float)
data['Volume'] = data['Volume'].astype(float)

data['Girth'] *=0.0254
data['Height'] *= 0.305
data['Volume'] *= 0.0283

data
# Out:
#       Girth  Height   Volume
# 1   0.21082  21.350  0.29149
# 2   0.21844  19.825  0.29149
# 3   0.22352  19.215  0.28866
# 4   0.26670  21.960  0.46412
# 5   0.27178  24.705  0.53204
# 6   0.27432  25.315  0.55751
# 7   0.27940  20.130  0.44148
# 8   0.27940  22.875  0.51506
# 9   0.28194  24.400  0.63958
# 10  0.28448  22.875  0.56317
# 11  0.28702  24.095  0.68486
# 12  0.28956  23.180  0.59430
# 13  0.28956  23.180  0.60562
# 14  0.29718  21.045  0.60279
# 15  0.30480  22.875  0.54053
# 16  0.32766  22.570  0.62826
# 17  0.32766  25.925  0.95654
# 18  0.33782  26.230  0.77542
# 19  0.34798  21.655  0.72731
# 20  0.35052  19.520  0.70467
# 21  0.35560  23.790  0.97635
# 22  0.36068  24.400  0.89711
# 23  0.36830  22.570  1.02729
# 24  0.40640  21.960  1.08389
# 25  0.41402  23.485  1.20558
# 26  0.43942  24.705  1.56782
# 27  0.44450  25.010  1.57631
# 28  0.45466  24.400  1.64989
# 29  0.45720  24.400  1.45745
# 30  0.45720  24.400  1.44330
# 31  0.52324  26.535  2.17910
# 32      NaN     NaN      NaN

# %%
import pandas as pan
data = pan.read_csv('trees.csv', 
                   names = ['I', 'Girth', 'Height', 'Volume'])
del data['I']
data.drop(0, inplace=True)
data['Girth'] = data['Girth'].astype(float)
data['Height'] = data['Height'].astype(float)
data['Volume'] = data['Volume'].astype(float)

data['Girth'] *=0.0254
data['Height'] *= 0.305
data['Volume'] *= 0.0283

data.round(1)
# Out:
#     Girth  Height  Volume
# 1     0.2    21.3     0.3
# 2     0.2    19.8     0.3
# 3     0.2    19.2     0.3
# 4     0.3    22.0     0.5
# 5     0.3    24.7     0.5
# 6     0.3    25.3     0.6
# 7     0.3    20.1     0.4
# 8     0.3    22.9     0.5
# 9     0.3    24.4     0.6
# 10    0.3    22.9     0.6
# 11    0.3    24.1     0.7
# 12    0.3    23.2     0.6
# 13    0.3    23.2     0.6
# 14    0.3    21.0     0.6
# 15    0.3    22.9     0.5
# 16    0.3    22.6     0.6
# 17    0.3    25.9     1.0
# 18    0.3    26.2     0.8
# 19    0.3    21.7     0.7
# 20    0.4    19.5     0.7
# 21    0.4    23.8     1.0
# 22    0.4    24.4     0.9
# 23    0.4    22.6     1.0
# 24    0.4    22.0     1.1
# 25    0.4    23.5     1.2
# 26    0.4    24.7     1.6
# 27    0.4    25.0     1.6
# 28    0.5    24.4     1.6
# 29    0.5    24.4     1.5
# 30    0.5    24.4     1.4
# 31    0.5    26.5     2.2
# 32    NaN     NaN     NaN

# %%
max_girth = (data['Girth'].round(2)).max()
max_girth
# Out:
# 0.52

# %%
max_girth = (data['Girth'].round(2)).max()
max_height = (data['Height'].round(2)).max()
max_vol = (data['Volume'].round(2)).max()

min_girth = (data['Girth'].round(2)).min()
min_height = (data['Height'].round(2)).min()
min_vol = (data['Volume'].round(2)).min()

avg_girth = data['Girth'].mean()
avg_girth
# Out:
# 0.33650903225806444

# %%
max_girth = (data['Girth'].round(2)).max()
max_height = (data['Height'].round(2)).max()
max_vol = (data['Volume'].round(2)).max()

min_girth = (data['Girth'].round(2)).min()
min_height = (data['Height'].round(2)).min()
min_vol = (data['Volume'].round(2)).min()

avg_girth = round(data['Girth'].mean(), 2)
avg_girth
# Out:
# 0.34

# %%
max_girth = (data['Girth'].round(2)).max()
max_height = (data['Height'].round(2)).max()
max_vol = (data['Volume'].round(2)).max()

min_girth = (data['Girth'].round(2)).min()
min_height = (data['Height'].round(2)).min()
min_vol = (data['Volume'].round(2)).min()

avg_girth = round(data['Girth'].mean(), 2)
avg_height = round(data['Height'].mean(), 2)
avg_volume = round(data['Volume'].mean(), 2)

med_girth = (data['Girth'].round(2)).median()
med_girth
# Out:
# 0.33

# %%
max_girth = (data['Girth'].round(2)).max()
max_height = (data['Height'].round(2)).max()
max_vol = (data['Volume'].round(2)).max()

min_girth = (data['Girth'].round(2)).min()
min_height = (data['Height'].round(2)).min()
min_vol = (data['Volume'].round(2)).min()

avg_girth = round(data['Girth'].mean(), 2)
avg_height = round(data['Height'].mean(), 2)
avg_volume = round(data['Volume'].mean(), 2)

med_girth = (data['Girth'].round(2)).median()
med_height = (data['Height'].round(2)).median()
med_volume = (data['Volume'].round(2)).median()

mod_girth = (data['Girth'].round(2)).mode()
mod_girth
# Out:
# 0    0.28
# Name: Girth, dtype: float64

# %%
max_girth = (data['Girth'].round(2)).max()
max_height = (data['Height'].round(2)).max()
max_vol = (data['Volume'].round(2)).max()

min_girth = (data['Girth'].round(2)).min()
min_height = (data['Height'].round(2)).min()
min_vol = (data['Volume'].round(2)).min()

avg_girth = round(data['Girth'].mean(), 2)
avg_height = round(data['Height'].mean(), 2)
avg_volume = round(data['Volume'].mean(), 2)

med_girth = (data['Girth'].round(2)).median()
med_height = (data['Height'].round(2)).median()
med_volume = (data['Volume'].round(2)).median()

mod_girth = (data['Girth'].round(2)).mode()
mod_height = (data['Height'].round(2)).mode()
mod_volume = (data['Volume'].round(2)).mode()
mod_volume
# Out:
# 0    0.29
# Name: Volume, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.plot(data['Girth'])
plt.title('Girth')
plt.ylabel('Meters')
# Out:
# Text(0, 0.5, 'Meters')

# %%
plt.plot(data['Height'])
plt.title('Height')
plt.ylabel('Meters')
# Out:
# Text(0, 0.5, 'Meters')

# %%
plt.plot(data['Volume'])
plt.title('Volume')
plt.ylabel('Cubic Meters')
# Out:
# Text(0, 0.5, 'Cubic Meters')
